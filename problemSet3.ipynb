# %%
#Question 1:

"""Occupations
Step 1. Import the necessary libraries
Step 2. Import the dataset from this address.
Step 3. Assign it to a variable called users
Step 4. Discover what is the mean age per occupation"""

import pandas as pd
import numpy as np

users= pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep='|', index_col='user_id')
users.groupby('occupation').age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
#Question 1: Step 5. Discover the Male ratio per occupation and sort it from the most to the least


ratio = users.pivot_table(index='occupation', columns='gender', aggfunc='size', fill_value = 0)

Total = ratio[['F', 'M']].sum(axis = 1)
ratio['MaleRatio'] = round(100 * ratio['M'] / Total, 1)
ratio['FemaleRatio'] = round(100 * ratio['F'] / Total, 1)

ratio.sort_values(by='MaleRatio', ascending=False)
# Out:
# gender          F    M  MaleRatio  FemaleRatio
# occupation
# doctor          0    7      100.0          0.0
# engineer        2   65       97.0          3.0
# technician      1   26       96.3          3.7
# retired         1   13       92.9          7.1
# programmer      6   60       90.9          9.1
# executive       3   29       90.6          9.4
# scientist       3   28       90.3          9.7
# entertainment   2   16       88.9         11.1
# lawyer          2   10       83.3         16.7
# salesman        3    9       75.0         25.0
# educator       26   69       72.6         27.4
# student        60  136       69.4         30.6
# other          36   69       65.7         34.3
# marketing      10   16       61.5         38.5
# writer         19   26       57.8         42.2
# none            4    5       55.6         44.4
# administrator  36   43       54.4         45.6
# artist         13   15       53.6         46.4
# librarian      29   22       43.1         56.9
# ...

# %%
#Question 1: Step 6. For each occupation, calculate the minimum and maximum ages

users.groupby('occupation').age.agg(['min','max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %%
#Question 1 Step 7. For each combination of occupation and sex, calculate the mean age

users.groupby(['occupation', 'gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
#Question 1: Step 8. For each occupation present the percentage of women and men

ratio.drop(ratio.columns[[0,1]], axis = 1, inplace = False)
# Out:
# gender         MaleRatio  FemaleRatio
# occupation
# administrator       54.4         45.6
# artist              53.6         46.4
# doctor             100.0          0.0
# educator            72.6         27.4
# engineer            97.0          3.0
# entertainment       88.9         11.1
# executive           90.6          9.4
# healthcare          31.2         68.8
# homemaker           14.3         85.7
# lawyer              83.3         16.7
# librarian           43.1         56.9
# marketing           61.5         38.5
# none                55.6         44.4
# other               65.7         34.3
# programmer          90.9          9.1
# retired             92.9          7.1
# salesman            75.0         25.0
# scientist           90.3          9.7
# student             69.4         30.6
# technician          96.3          3.7
# writer              57.8         42.2

# %%
#Question 2:

"""Euro Teams
    Step 1. Import the necessary libraries
    Step 2. Import the dataset from this address
    Step 3. Assign it to a variable called euro12
    Step 4. Select only the Goal column
"""

import pandas as pd
import numpy as np

euro12=pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')

euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
#Question 2: Step 5. How many team participated in the Euro2012?

euro12.shape[0]
# Out:
# 16

# %%
#Question 2: Step 6. What is the number of columns in the dataset?

len(euro12.columns)
# Out:
# 35

# %%
#Question 2: Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

discipline=pd.DataFrame(euro12, columns=['Team','Yellow Cards', 'Red Cards'])
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
#Question 2: Step 8. Sort the teams by Red Cards, then to Yellow Cards

discipline.sort_values(['Red Cards','Yellow Cards'], ascending=[True, True])
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %%
#Question 2: Step 9. Calculate the mean Yellow Cards given per Team

euro12['Yellow Cards'].mean()
# Out:
# 7.4375

# %%
#Question 2: Step 10. Filter teams that scored more than 6 goalsStep 11. Select the teams that start with G

euro12[euro12.Goals > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
#Question 2: Step 11. Select the teams that start with G

euro12[euro12.Team.str[0] == 'G']
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
#Question 2: Step 12. Select the first 7 columns

euro12.iloc[: , 0:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#Question 2: Step 13. Select all columns except the last 3

euro12.iloc[: , :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#Question 2: Step 14. Present only the Shooting Accuracy from England, Italy and Russia

acc = euro12.set_index('Team')
accuracy = acc.loc[['England','Italy','Russia'],['Shooting Accuracy']]
accuracy
# Out:
#         Shooting Accuracy
# Team
# England             50.0%
# Italy               43.0%
# Russia              22.5%

# %%
#Question 3:
"""Step 1. Import the necessary libraries
   Step 2. Create 3 differents Series, each of length 100, as follows:
        • The first a random number from 1 to 4
        • The second a random number from 1 to 3
        • The third a random number from 10,000 to 30,000  
   Step 3. Create a DataFrame by joinning the Series by column
"""

import pandas as pd
import numpy as np

first_random = pd.Series(np.random.randint(1, high=5, size=100, dtype='l'))
second_random = pd.Series(np.random.randint(1, high=4, size=100, dtype='l'))
third_random = pd.Series(np.random.randint(10000, high=30001, size=100, dtype='l'))

Housing = pd.concat([first_random, second_random, third_random], axis = 1)
Housing
# Out:
#     0  1      2
# 0   2  3  29741
# 1   3  2  13553
# 2   4  3  14742
# 3   2  2  24558
# 4   4  1  24464
# .. .. ..    ...
# 95  1  2  18506
# 96  4  3  13963
# 97  3  1  22465
# 98  1  1  22198
# 99  2  3  25526
#
# [100 rows x 3 columns]

# %%
#Question 3: Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter

Housing.rename(columns = {0: 'bedrs', 1: 'bathrs', 2: 'price_sqr_meter'}, inplace=True)
Housing
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       2       3            29741
# 1       3       2            13553
# 2       4       3            14742
# 3       2       2            24558
# 4       4       1            24464
# ..    ...     ...              ...
# 95      1       2            18506
# 96      4       3            13963
# 97      3       1            22465
# 98      1       1            22198
# 99      2       3            25526
#
# [100 rows x 3 columns]

# %%
#Question 3: Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

bigcolumn = pd.DataFrame(pd.concat([first_random, second_random, third_random], axis = 1))
bigcolumn
# Out:
#     0  1      2
# 0   2  3  29741
# 1   3  2  13553
# 2   4  3  14742
# 3   2  2  24558
# 4   4  1  24464
# .. .. ..    ...
# 95  1  2  18506
# 96  4  3  13963
# 97  3  1  22465
# 98  1  1  22198
# 99  2  3  25526
#
# [100 rows x 3 columns]

# %%
#Question 3: Step 6. Ops it seems it is going only until index 99. Is it true?

len(bigcolumn)
# Out:
# 100

# %%
#Question 3: Step 7. Reindex the DataFrame so it goes from 0 to 299

bigcolumn.reset_index(inplace = True) 
bigcolumn.iloc[0:299,]
# Out:
#      index      0
# 0        0      2
# 1        1      4
# 2        2      1
# 3        3      2
# 4        4      1
# ..     ...    ...
# 294     94  10123
# 295     95  19006
# 296     96  29623
# 297     97  24391
# 298     98  12845
#
# [299 rows x 2 columns]

# %%
#Question 4:

#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html

"""Step 1. Import the necessary libraries
   Step 2. Import the dataset from the attached file wind.txt
   Step 3. Assign it to a variable called data and replace the first 3 columns by a proper
           datetime index
   Step 4. Year 2061? Do we really have data from this year? Create a function to fix it
           and apply it.
   Step 5. Set the right dates as the index. Pay attention at the data type, it should be
           datetime64[ns]
"""

import pandas as pd
import numpy as np
import datetime

data = pd.read_csv('https://learn-us-east-1-prod-fleet01-xythos.content.blackboardcdn.com/blackboard.learn.xythos.prod/599c7a2702a96/12679944?X-Blackboard-Expiration=1639688400000&X-Blackboard-Signature=Z%2FVH5e5yRQFrbtHuAYzBSAXITnpwFIfe2oJYs3BGIeQ%3D&X-Blackboard-Client-Id=100784&response-cache-control=private%2C%20max-age%3D21600&response-content-disposition=inline%3B%20filename%2A%3DUTF-8%27%27wind.txt&response-content-type=text%2Fplain&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEKj%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJGMEQCIBwMPPSwG9Lz7YRT1IPOxtYBZRv7F4b76HTi%2Fua4jLRJAiA9PwgmVrZmnKLlgiZT3v6idbdA7mZUiurejwXhWJJO6iqDBAiR%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDU1NjkwMzg2MTM2MSIMEJHFHPal%2FWUC8BLRKtcDssv2J%2F1Pj93ZNDm05fVJIWSP0Aj%2FAz%2FJmj9BwsE0y9dbZevvr3EkdAiAs%2FtfGRwNWvJ0o9rfe5apBvUPJ9HFEEKfVMu%2BMvbkTiUwnH2INJZSMnPcysSO2y%2BmaUlOd6hEM2OWtQRTSsO0%2FK%2BfxStABKQOgygLYgVjjh%2BiL0hMwvTXW6FWfBYJYjLv0IFsDlQZielxccmhZf8JEHwHdwmBjvJoJfmZk0N%2FE02j2SRP7JWIAPNklGYr1JtbZ9j6Jfk0%2FOjb5C%2FpujrClYa4b6L1VxSQe7pFGYJA40%2FkjEecnbPeRs28PgV0oobbLPnqI8Y8d9uPJg1ypk3AusSRI67cC4kPih35z7tZDQS75%2BzV7CU9yVXBLujE4b7PDhH%2BtoAGMs3VDJtZXXv1tUc0eraThP9qsPEm%2FF7pZUudba3HAMLAG95Xp2gX7OY8WY1XWc0A4R8CQ1ExozCI46CHchTOW2pt4t4Js5NiKT3dhBpUb7pprwJCYvWM3PIED%2B9LFQyacHGiPCnrJw1jsAaPBDpKXAPuzRCQshQfqyB9ioZw3u%2BSpVt2Swl%2B4BIGm5Ax8lnFUt4zIVLgT6a4%2Bx7vqTNYYcCLg2J3Z7P0EP8RJlXX%2FHB8zJevtUWWML%2B87Y0GOqYBV6DZEG%2BSuVtZAlrIz3fHd8KE04ny0ynAF6vMNs5o1vq9UJMnKxs3B76yICDUrmSF0fcytMUB2ckcUXef6FPiN%2BvkjhyxztTqAIBiVLeVSpbMzB7DQToGXh%2FMLGRn%2FgNl62VXmxShwllZyU20p6GbwHx6al8KcZVhOo5Rs%2BEv4VZr0TT7N%2B4lZXlcSlDXCuan2DwI%2FxQA7tmHPULlrfe1Iupj324GjA%3D%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20211216T150000Z&X-Amz-SignedHeaders=host&X-Amz-Expires=21600&X-Amz-Credential=ASIAYDKQORRYRU5WRESQ%2F20211216%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=094fabbd20a6dbc926a4eb84247c2b377d2dadfd8326de7707853b829b96d37b', header=None, delim_whitespace=True)

data.columns = data.iloc[0]
data = data.drop([0])
data['Yr'] = data['Yr'].astype(int)
data['Yr'] =data.apply(lambda x: x['Yr'] + 1900, axis = 1)
data['Yr'] = data['Yr'].astype(str)
data['Yr'] = data["Mo"] + '-' + data["Dy"] + '-' + data["Yr"] 
SERIES = data['Yr'].astype('datetime64')
data['Yr'] = SERIES
data = data.drop(['Mo', 'Dy'], axis = 1)
data = data.rename(columns={'Yr':'Date'})

y = pd.DataFrame(data)

data = data.set_index('Date')
data
# Out:
# 0             RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Date
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
# 0             CLO    BEL    MAL
# Date
# 1961-01-01  12.58  18.50  15.04
# ...

# %%
#Question 4: Step 6. Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below.

data.isnull().sum()
# Out:
# 0
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
#Question 4: Step 7. Compute how many non-missing values there are in total.

data = data.astype('float')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6574 entries, 1961-01-01 to 1978-12-31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RPT     6568 non-null   float64
#  1   VAL     6571 non-null   float64
#  2   ROS     6572 non-null   float64
#  3   KIL     6569 non-null   float64
#  4   SHA     6572 non-null   float64
#  5   BIR     6574 non-null   float64
#  6   DUB     6571 non-null   float64
#  7   CLA     6572 non-null   float64
#  8   MUL     6571 non-null   float64
#  9   CLO     6573 non-null   float64
#  10  BEL     6574 non-null   float64
#  11  MAL     6570 non-null   float64
# dtypes: float64(12)
# memory usage: 667.7 KB

# %%
#Question 4: Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.

x=data.mean()
x.mean()
# Out:
# 10.227982360836924

# %%
#Question 4: Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days

loc_stats=pd.DataFrame()
loc_stats['min']=data.min()
loc_stats['max']=data.max()
loc_stats['mean']=data.mean()
loc_stats['std']=data.std()
loc_stats
# Out:
#       min    max       mean       std
# 0
# RPT  0.67  35.80  12.362987  5.618413
# VAL  0.21  33.37  10.644314  5.267356
# ROS  1.50  33.84  11.660526  5.008450
# KIL  0.00  28.46   6.306468  3.605811
# SHA  0.13  37.54  10.455834  4.936125
# BIR  0.00  26.16   7.092254  3.968683
# DUB  0.00  30.37   9.797343  4.977555
# CLA  0.00  31.08   8.495053  4.499449
# MUL  0.00  25.88   8.493590  4.166872
# CLO  0.04  28.21   8.707332  4.503954
# BEL  0.13  42.38  13.121007  5.835037
# MAL  0.67  42.54  15.599079  6.699794

# %%
#Question 4: Step 10.Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.A different set of numbers for each day.

day_stats=pd.DataFrame()
day_stats['min']=data.min(axis=1)
day_stats['max']=data.max(axis=1)
day_stats['mean']=data.mean(axis=1)
day_stats['std']=data.std(axis=1)

day_stats
# Out:
#              min    max       mean       std
# Date
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356
# ...          ...    ...        ...       ...
# 1978-12-27  8.08  40.08  16.708333  7.868076
# 1978-12-28  5.00  41.46  15.150000  9.687857
# 1978-12-29  8.71  29.58  14.890000  5.756836
# 1978-12-30  9.13  28.79  15.367500  5.540437
# 1978-12-31  9.59  27.29  15.402500  5.702483
#
# [6574 rows x 4 columns]

# %%
#Question 4: Step 11. Find the average windspeed in January for each location.Treat January 1961 and January 1962 both as January

y[['RPT','VAL','ROS','KIL','SHA','BIR','DUB','CLA','MUL','CLO','BEL','MAL']] = y[['RPT','VAL','ROS','KIL','SHA','BIR','DUB','CLA','MUL','CLO','BEL','MAL']].astype('float')
y.groupby(pd.Grouper(key = 'Date', axis = 0, freq = 'M')).mean()
# Out:
# 0                 RPT        VAL        ROS       KIL        SHA        BIR  \
# Date
# 1961-01-31  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02-28  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03-31  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-31   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...               ...        ...        ...       ...        ...        ...
# 1978-08-31   9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09-30  10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10-31   9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11-30  16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12-31  16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %%
#Question 4: Step 12. Downsample the record to a yearly frequency for each location.

data.resample('Y').sum()
# Out:
# 0               RPT      VAL      ROS      KIL      SHA      BIR      DUB  \
# Date
# 1961-12-31  4427.85  3747.35  4124.54  2511.92  3950.08  2821.35  3523.68
# 1962-12-31  4457.88  3690.31  4282.44  2533.60  3890.14  2698.47  4022.56
# 1963-12-31  4676.91  3955.50  4577.52  2675.47  4279.30  3078.67  4042.63
# 1964-12-31  4525.10  3996.78  4430.20  2484.33  4192.34  2770.94  3754.85
# 1965-12-31  4544.75  4042.57  4324.80  2503.34  4024.05  2729.51  3875.83
# 1966-12-31  4913.62  4218.38  4387.53  2681.19  4308.84  2844.69  3861.63
# 1967-12-31  4649.06  4011.71  4284.88  2607.35  4245.22  2689.38  3887.99
# 1968-12-31  4331.84  3831.36  4175.97  2370.83  3938.44  2220.64  3242.46
# 1969-12-31  4075.72  3549.15  3979.23  2105.31  3603.98  2259.34  3126.04
# 1970-12-31  4599.12  3915.33  4281.54  2269.27  3857.09  2777.45  3507.61
# 1971-12-31  4114.69  3319.74  4047.24  1913.15  3445.72  2225.46  3060.85
# 1972-12-31  4561.81  3865.44  4413.35  2170.27  3451.53  2327.33  3551.85
# ...

# %%
#Question 4 - Step 13. Downsample the record to a monthly frequency for each location.

data.resample('M').sum()
# Out:
# 0              RPT     VAL     ROS     KIL     SHA     BIR     DUB     CLA  \
# Date
# 1961-01-31  445.24  359.65  416.38  239.84  321.11  266.23  346.73  277.36
# 1961-02-28  455.54  419.31  389.92  249.23  387.86  306.25  332.94  331.69
# 1961-03-31  326.70  350.19  333.34  218.52  325.79  274.87  298.97  304.72
# 1961-04-30  321.68  282.83  299.94  174.92  253.05  194.85  207.76  212.84
# 1961-05-31  305.69  265.50  335.36  177.16  294.20  203.82  228.12  253.49
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 1978-08-31  299.00  256.04  280.00  139.59  228.41  183.99  175.16  167.95
# 1978-09-30  327.41  326.85  319.05  171.75  311.16  278.35  323.71  287.49
# 1978-10-31  306.83  268.80  288.17  146.36  264.28  210.00  251.58  227.47
# 1978-11-30  484.55  444.08  405.24  219.52  344.25  262.29  344.77  289.72
# 1978-12-31  501.44  426.19  484.69  219.94  353.36  286.49  374.40  316.04
#
# 0              MUL     CLO     BEL     MAL
# Date
# ...

# %%
#Question 4 - Step 14. Downsample the record to a weekly frequency for each location.

data.resample('7D').sum()
# Out:
# 0              RPT     VAL     ROS    KIL     SHA    BIR     DUB    CLA  \
# Date
# 1961-01-01   98.87   74.13   78.96  48.30   56.70  47.63   76.81  42.33
# 1961-01-08   86.20   62.85   79.58  35.95   53.70  39.67   64.54  48.53
# 1961-01-15   94.88   72.83   92.71  44.50   54.31  49.55   57.92  54.92
# 1961-01-22  128.87   94.96  115.21  73.67  104.82  89.60   96.08  92.91
# 1961-01-29   95.79  115.38   90.92  63.64  103.36  71.41   93.47  64.55
# ...            ...     ...     ...    ...     ...    ...     ...    ...
# 1978-12-03  141.47  133.13  120.45  65.40  108.17  90.88  105.31  88.59
# 1978-12-10  132.36  122.18  113.41  60.83   92.33  63.37   82.21  68.43
# 1978-12-17   79.29   53.64   88.13  25.45   52.73  38.66   44.80  52.88
# 1978-12-24   93.00   70.83   97.08  40.75   60.63  56.12   88.96  70.96
# 1978-12-31   20.33   17.41   27.29   9.59   12.08  10.13   19.25  11.63
#
# 0             MUL    CLO     BEL     MAL
# Date
# 1961-01-01  60.62  61.60   89.25   91.25
# ...

# %%
#Question 4 -Step 15 - Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

weekly = data.resample('W').agg(['min','max','mean','std'])
weekly.loc[weekly.index[1:53], "RPT":"MAL"] .head(10)
# Out:
#               RPT                                VAL                    \
#               min    max       mean       std    min    max       mean
# Date
# 1961-01-08  10.58  18.50  13.541429  2.631321   6.63  16.88  11.486667
# 1961-01-15   9.04  19.75  12.468571  3.555392   3.54  12.08   8.967143
# 1961-01-22   4.92  19.83  13.204286  5.337402   3.42  14.37   9.862857
# 1961-01-29  13.62  25.04  19.880000  4.619061   9.96  23.91  16.141429
# 1961-02-05  10.58  24.21  16.827143  5.251408   9.46  24.21  15.460000
# 1961-02-12  16.00  24.54  19.684286  3.587677  11.54  21.42  16.417143
# 1961-02-19   6.04  22.50  15.130000  5.064609  11.63  20.17  15.091429
# 1961-02-26   7.79  25.80  15.221429  7.020716   7.08  21.50  13.625714
# 1961-03-05  10.96  13.33  12.101429  0.997721   8.83  17.00  12.951429
# 1961-03-12   4.88  14.79   9.376667  3.732263   8.08  16.96  11.578571
#
#                         ROS         ...        CLO              BEL         \
# ...

# %%
#Question 5:

"""Step 1. Import the necessary libraries
   Step 2. Import the dataset from this address.
   Step 3. Assign it to a variable called chipo.
   Step 4. See the first 10 entries
"""

import pandas as pd
import numpy as np

chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t')
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#Question 5: Step 5- What is the number of observations in the dataset?

chipo.shape[0]
# Out:
# 4622

# %%
#Question 5: Step 6- What is the number of columns in the dataset?

len(chipo.columns)
# Out:
# 5

# %%
#Question 5: Step 7- Print the name of all the columns.

chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#Question 5: Step 8- How is the dataset indexed?

chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#Question 5: Step 9- Which was the most-ordered item?

most_ordered= chipo.item_name.value_counts()
most_ordered.head(1)
# Out:
# Chicken Bowl    726
# Name: item_name, dtype: int64

# %%
#Question 5: Step 10- For the most-ordered item, how many items were ordered?

len(most_ordered)
# Out:
# 50

# %%
#Question 5: Step 11- What was the most ordered item in the choice_description column?

most_ordered_item =chipo.choice_description.value_counts()
most_ordered_item.head(1)
# Out:
# [Diet Coke]    134
# Name: choice_description, dtype: int64

# %%
#Question 5: Step 12- How many items were orderd in total?

chipo.quantity.sum()
# Out:
# 4972

# %%
#Question 5: Step 13


""" • Turn the item price into a float
    • Check the item price type
    • Create a lambda function and change the type of item price
    • Check the item price type """

def turn(x):
    return float(x[1 : -1])
chipo.item_price = chipo.item_price.apply(turn)
chipo.item_price
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
#Question 5: Step 14 - How much was the revenue for the period in the dataset?

chipo.item_price.sum()
# Out:
# 34500.16

# %%
#Question 5: Step 15 - How many orders were made in the period?

len(chipo['order_id'].value_counts())
# Out:
# 1834

# %%
#Question 5: Step 16 - What is the average revenue amount per order?

averageRevenue = chipo.groupby(['order_id']).sum()
averageRevenue
# Out:
#           quantity  item_price
# order_id
# 1                4       11.56
# 2                2       16.98
# 3                2       12.67
# 4                2       21.00
# 5                2       13.70
# ...            ...         ...
# 1830             2       23.00
# 1831             3       12.90
# 1832             2       13.20
# 1833             2       23.50
# 1834             3       28.75
#
# [1834 rows x 2 columns]

# %%
averageRevenue['item_price'].mean()
# Out:
# 18.81142857142869

# %%
#Question 5: Step 17 How many different items are sold?

diffItems = len(chipo['item_name'].unique())
diffItems
# Out:
# 50

# %%
#Question 6:

import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

iries = pd.read_csv('C:\\Users\\Manoghna Kola\\Downloads\\us-marriages-divorces-1867-2014.csv')

iries.head()

x='Year'
y={'Marriages', 'Divorces'}

z=iries.plot.line(x, y)
z.set_xlabel('Year', fontweight='bold')
z.set_ylabel('Marriages vs Divorces', fontweight='bold')
z.set_title('Marriages and Divorces in US from the year 1847 to 2014', color = 'Blue', fontsize=14, fontweight='bold')
z.legend()

# %%
#Question 7:

import pandas as pd 

import matplotlib.pyplot as plt

# %matplotlib inline

us_marriages_divorces = pd.read_csv('C:\\Users\\Manoghna Kola\\Downloads\\us-marriages-divorces-1867-2014.csv')

us_marriages_divorces.set_index('Year', inplace = True)

setYears = us_marriages_divorces.loc[[1900,1950,2000],['Marriages','Divorces']]
z=setYears.plot.bar(title="Number of Marriages and Divorces in US in the years 1900, 1950 and 2000")
z.legend()

# %%
#Question 8

import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

actorKills = pd.read_csv('C:\\Users\\Manoghna Kola\\Downloads\\actor_kill_counts.csv')

sortActorKills=actorKills.sort_values(['Count','Actor'], ascending=[True, False]).plot.barh('Actor','Count')

sortActorKills.set_xlabel('Count of Kills', fontweight='bold')
sortActorKills.set_ylabel('Actor', fontweight='bold')
sortActorKills.set_title('Deadliest actors in Hollywood', color = 'Red', fontsize=14, fontweight='bold')
sortActorKills.legend()

# %%
#Question 9

import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

romanEmperor = pd.read_csv('C:\\Users\\Manoghna Kola\\Downloads\\roman-emperor-reigns.csv')
assasination = romanEmperor.loc[(romanEmperor['Cause_of_Death']=='Assassinated')]

fig, ax=plt.subplots(figsize=(8, 8))

plt.pie(assasination,autopct="%.1f%%");
ax.set_title('Roman Emperors that were assassinated', color = 'Green', fontsize=16, fontweight='bold')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-75f9bf9fd9b2> in <module>
#      10 fig, ax=plt.subplots(figsize=(8, 8))
#      11
# ---> 12 plt.pie(assasination,autopct="%.1f%%");
#      13 ax.set_title('Roman Emperors that were assassinated', color = 'Green', fontsize=16, fontweight='bold')
#      14
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2825         textprops=None, center=(0, 0), frame=False,
#    2826         rotatelabels=False, *, normalize=None, data=None):
# -> 2827     return gca().pie(
#    2828         x, explode=explode, labels=labels, colors=colors,
#    2829         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ...

# %%
#Question 10:

import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

arcadeRevenueDoctorate = pd.read_csv('C:\\Users\\Manoghna Kola\\Downloads\\arcade-revenue-vs-cs-doctorates.csv')


sns.set(font_scale=2)

arc = arcadeRevenueDoctorate['Total Arcade Revenue (billions)']
doc = arcadeRevenueDoctorate['Computer Science Doctorates Awarded (US)']

fig, ax=plt.subplots(figsize=(10, 10), dpi=100)
colors = ['#C4E57D','#2AC280','#FFAE39','#DC5B3B','#52E397','#C5CBA3','#9CD5F6','#6E50D9','#9A5E59','#9BC8F5']

ax.set_title('Total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between 2000 and 2009', color = 'Purple', fontsize=14, fontweight='bold')
sns.scatterplot(x='Total Arcade Revenue (billions)', y='Computer Science Doctorates Awarded (US)', hue='Year', s=400, palette=colors, data = arcadeRevenueDoctorate)
# Out:
# <AxesSubplot:title={'center':'Total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between 2000 and 2009'}, xlabel='Total Arcade Revenue (billions)', ylabel='Computer Science Doctorates Awarded (US)'>
